# %%
from aff2newdataset import Aff2CompDatasetNew
import matplotlib.pyplot as plt
dataset = Aff2CompDatasetNew(root_dir='aff2_processed')
values = 0
dat = dataset.__getitem__(10)
print(dat['clip'].size())
# Out:
# {'vid_name': ['426', '00098.jpg'], 'valience': '0.322', 'arousal': '0.314', 'expressions': ['4', '0', '0', '0', '1', '0', '0', '1'], 'action_units': ['0', '0', '0', '1', '0']}
# torch.Size([4, 8, 112, 112])

# %%
print(values/len)

# %%
import librosa
def plot_spectrogram(spec, title=None, ylabel='freq_bin', aspect='auto', xmax=None):
  fig, axs = plt.subplots(1, 1)
  axs.set_title(title or 'Spectrogram (db)')
  axs.set_ylabel(ylabel)
  axs.set_xlabel('frame')
  im = axs.imshow(librosa.power_to_db(spec), origin='lower', aspect=aspect)
  if xmax:
    axs.set_xlim((0, xmax))
  fig.colorbar(im, ax=axs)
  plt.show(block=False)

# %%
print(spectrogram.size())
plot_spectrogram(spectrogram[0],title="MelSpectrogram",ylabel="mel freq")
# Out:
# torch.Size([1, 128, 2780])

# %%
print( dataset.__getitem__(0).keys())
print(dataset.__getitem__(0)['path'])
